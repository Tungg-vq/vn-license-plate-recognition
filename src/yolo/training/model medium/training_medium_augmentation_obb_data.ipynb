# %% [markdown]
# OPTUNA

# %% [markdown]
# import optuna
# import gc
# import torch
# from ultralytics import YOLO
#
# def objective(trial):
#     lr0 = trial.suggest_float('lr0', 1e-4, 1e-2, log=True)
#     optimizer = trial.suggest_categorical('optimizer', ['AdamW', 'SGD'])
#     momentum = trial.suggest_float('momentum', 0.6, 0.98)
#     imgsz = trial.suggest_categorical('imgsz', [480, 544, 640])
#
#     translate = trial.suggest_float('translate', 0.0, 0.3)
#     scale = trial.suggest_float('scale', 0.0, 0.5)
#     degrees = trial.suggest_float('degrees', 0.0, 15.0)
#     mosaic = trial.suggest_float('mosaic', 0.5, 1.0)
#
#     model = YOLO('yolo11m-obb.pt')
#
#     def check_prune(trainer):
#         epoch = trainer.epoch
#
#         map50 = trainer.metrics.get('metrics/mAP50(B)', 0.0)
#         trial.report(map50, epoch)
#         if trial.should_prune():
#             raise optuna.exceptions.TrialPruned()
#
#     model.add_callback('on_fit_epoch_end', check_prune)
#
#     try:
#         results = model.train(
#             data='/kaggle/working/yolo_dataset/data.yaml',
#             epochs=50,
#             batch=16,
#             workers=2,
#             device=0,
#             save=False,
#
#             lr0=lr0, optimizer=optimizer, momentum=momentum, imgsz=imgsz,
#             translate=translate, scale=scale, degrees=degrees, mosaic=mosaic,
#             shear=2.0, perspective=0.001,
#
#             fliplr=0.0, flipud=0.0, mixup=0.0, erasing=0.0,
#
#             project='/kaggle/working/Optuna_OBB_Aug',
#             name=f'trial_{trial.number}',
#             verbose=False
#         )
#
#
#         map50 = results.box.map50
#
#         del model
#         del results
#         gc.collect()
#         torch.cuda.empty_cache()
#
#         return map50
#
#     except optuna.exceptions.TrialPruned:
#         del model
#         gc.collect()
#         torch.cuda.empty_cache()
#         raise optuna.exceptions.TrialPruned()
#
# if __name__ == "__main__":
#     pruner = optuna.pruners.MedianPruner(n_startup_trials=3, n_warmup_steps=3)
#     study = optuna.create_study(direction='maximize', pruner=pruner)
#
#     study.optimize(objective, n_trials=30)
#
#     for key, value in study.best_params.items():
#         print(f"   - {key}: {value}")
#     print(f"Max mAP OBB: {study.best_value:.4f}")

# %% [markdown]
# TRAINING

# %%
from ultralytics import YOLO


model = YOLO('yolo11m-obb.pt')


results = model.train(
    data='/kaggle/working/yolo_dataset/data.yaml',
    epochs=300,          
    batch=16,
    device=0,
    save=True,          
    
    
    lr0=0.005959313965757247,
    optimizer='AdamW',
    momentum=0.8280445149945385,
    imgsz=480,        
    

    translate=0.2874023592989939, 
    scale=0.34763679142112364, 
    degrees=1.4045641721031865, 
    mosaic=0.944783725873273,
    
  
    shear=2.0,         
    perspective=0.001, 
    
   
    fliplr=0.0, flipud=0.0, mixup=0.0, erasing=0.0,
    
   
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, bgr=0.0, copy_paste=0.0,
    
  
    project='/kaggle/working/Final_Models',
    name='YOLOv11m_OBB_Chot_Ha'
)
